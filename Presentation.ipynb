# %% [markdown]
# <h1 style="text-align:center;font-style:italic;">If we knew what we were doing, it wouldn't be called research</h1>
#
# <p style="text-align:right">—widely attributed to Albert Einstein</p>

# %% [markdown]
# ## Exploratory computing
#
# ```python
# while True:
#     code = input('>>> ')
#     exec(code)
# ```
#
#
# <br><br>
# <img style="margin: 0 auto;" src="ipython_terminal_screenshot.png">

# %% [markdown]
# ## The notebook interface

# %%
# %matplotlib inline

# %%
import numpy as np, matplotlib.pyplot as plt
x = np.linspace(0, 20, num=500)
plt.plot(x, np.sin(.5*x**2))

# %% [markdown]
# ## Notebook documents
#
# * Reproducible papers
# * Lecture materials
# * Interactive books
# * Executable software documentation
#
# <img style="margin: 1em auto; border: 1px solid #ccc;" src="reproducible_paper.png">

# %% [markdown]
# ## Sharing notebooks
#
# Nbconvert to other formats
#
# <img style="margins: 1em auto;" src="file_icons_band.png">
#
# View notebooks online:
#
# <p style="text-align:center;font-size:1.5em">https://nbviewer.jupyter.org/</p>
#
# Github, Indico can view notebook files

# %% [markdown]
# ## Interactive output

# %%
from ipywidgets import interact

@interact(a=(0.1, 5.0), func=['sin', 'cos', 'tan'])
def plot_func(a=1, func='sin'):
    x = np.linspace(0.01, 2*np.pi, 200)
    y = getattr(np, func)(a/x)
    plt.plot(x, y)

# %% [markdown]
# ## Multiple languages
#
# <img style="margin: 2em auto;" src="lang_icons_band.png">
#
# <p style="text-align:center">and many more...</p>

# %% [markdown]
# ## How does it work?
#
# <img style="margin: 0 auto; height: 60vh;" src="ipy_kernel_and_terminal.png">

# %% [markdown]
# ## Message format
#
# ```json
# {
#   "header": {
#     "msg_type": "execute_request",
#     ...
#     },
#   "content": {
#     "code": "print('Hello, world')",
#     ...
#     },
#   ...
# }
# ```

# %% [markdown]
# ## How does it work?
#
# <img style="margin: 2em auto;" src="notebook_components.png">

# %% [markdown]
# ## Kernels for other languages
#
# <img style="margin: 2em auto;" src="kernel_models.png">

# %% [markdown]
# ## Future plans
#
# Modular UI, to build more varied applications - like:
#
# Thebe: https://oreillymedia.github.io/thebe/
#
# Hydrogen
#
#
# <img style="margin: 1em auto;" src="hydrogen_screenshot.png">

# %% [markdown]
# ## Future plans
#
# More support for notebook documents in various contexts - e.g.
#
# * As student assignments (see **nbgrader**)
# * As academic papers (see **cite2c**)
# * As docs for software projects
